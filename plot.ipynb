# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
labels = ['H and K', 'M and Y', 'X and T']
before_dim_reduction = [61.5, 54.4, 99.4]
after_dim_reduction = [85.1, 54.43, 99.3]

x = np.arange(len(labels))  # The label locations
width = 0.35  # The width of the bars

# Create the bar plot
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, before_dim_reduction, width, label='Before Dimension Reduction', color='blue')
rects2 = ax.bar(x + width/2, after_dim_reduction, width, label='After Dimension Reduction', color='green')

# Customize the plot
ax.set_ylabel('Accuracy (%)')
ax.set_title('Accuracy on final validation set for SVM')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper right')
ax.set_ylim([0, 100])  # Set the y-axis range from 0 to 100

# Add numerical labels above each bar
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1f}%'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
labels = ['H and K', 'M and Y', 'X and T']
before_dim_reduction = [89.2, 97.5, 93.7]
after_dim_reduction = [89.19, 97.5, 93.7]

x = np.arange(len(labels))  # The label locations
width = 0.35  # The width of the bars

# Create the bar plot
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, before_dim_reduction, width, label='Before Dimension Reduction', color='blue')
rects2 = ax.bar(x + width/2, after_dim_reduction, width, label='After Dimension Reduction', color='green')

# Customize the plot
ax.set_ylabel('Accuracy (%)')
ax.set_title('Accuracy on final validation set for SVM')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper right')
ax.set_ylim([0, 100])  # Set the y-axis range from 0 to 100

# Add numerical labels above each bar
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1f}%'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
labels = ['H and K', 'M and Y', 'X and T']
before_dim_reduction = [2.37, 4.36, 2.98]
after_dim_reduction = [2.07, 4.07, 2.48]

x = np.arange(len(labels))  # The label locations
width = 0.35  # The width of the bars

# Create the bar plot
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, before_dim_reduction, width, label='Before Dimension Reduction', color='blue')
rects2 = ax.bar(x + width/2, after_dim_reduction, width, label='After Dimension Reduction', color='green')

# Customize the plot
ax.set_ylabel('Time (s)')
ax.set_title('Total time for training the tuned model and test on final validation set for SVM(learning rate)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper right')

# Add numerical labels above each bar
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# Show the plot
plt.show()
